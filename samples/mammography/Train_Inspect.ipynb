# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Tesis_Pampam/Mammography_Mask_RCNN/samples/mammography/
# Out:
# /content/gdrive/MyDrive/Tesis_Pampam/Mammography_Mask_RCNN/samples/mammography

# %%
# !python utils/split_data.py --dataset_dir stuff/dataset/
# Out:
# Lens:  [0, 2252, 3218]
# Content from 0 to 2252
# Traceback (most recent call last):
#   File "utils/split_data.py", line 69, in <module>
#     shutil.copy2(src,dst)
#   File "/usr/lib/python3.6/shutil.py", line 263, in copy2
#     copyfile(src, dst, follow_symlinks=follow_symlinks)
#   File "/usr/lib/python3.6/shutil.py", line 121, in copyfile
#     with open(dst, 'wb') as fdst:
# KeyboardInterrupt

# %%
# !python utils/transform2dataset.py --dataset_dir stuff/dataset/ --csv stuff/dataset/annotations/complete_annotations.csv
# Out:
#                      class  ...                                              masks
# 0                MALIGNANT  ...  Calc-Training_P_00005_RIGHT_CC_1/1.3.6.1.4.1.9...
# 1                MALIGNANT  ...  Calc-Training_P_00005_RIGHT_MLO_1/1.3.6.1.4.1....
# 2                   BENIGN  ...  Calc-Training_P_00007_LEFT_CC_1/1.3.6.1.4.1.95...
# 3                   BENIGN  ...  Calc-Training_P_00007_LEFT_MLO_1/1.3.6.1.4.1.9...
# 4  BENIGN_WITHOUT_CALLBACK  ...  Calc-Training_P_00008_LEFT_CC_1/1.3.6.1.4.1.95...
#
# [5 rows x 4 columns]
# Reading:  stuff/dataset/annotations/complete_annotations.csv
# Records:  3218
