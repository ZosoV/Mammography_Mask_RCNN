# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/Tesis_Pampam/Mammography_Mask_RCNN/samples/mammography/utils/
# Out:
# /content/gdrive/MyDrive/Tesis_Pampam/Mammography_Mask_RCNN/samples/mammography/utils

# %%
# !python transform2dataset.py --csv ../stuff/dataset/annotations/complete_annotations.csv --dataset_dir ../stuff/dataset/images/CBIS-DDSM/ --output_dir ../stuff/dataset/
# Out:
#                      class  ...                                              masks
# 0                MALIGNANT  ...  Calc-Training_P_00005_RIGHT_CC_1/1.3.6.1.4.1.9...
# 1                MALIGNANT  ...  Calc-Training_P_00005_RIGHT_MLO_1/1.3.6.1.4.1....
# 2                   BENIGN  ...  Calc-Training_P_00007_LEFT_CC_1/1.3.6.1.4.1.95...
# 3                   BENIGN  ...  Calc-Training_P_00007_LEFT_MLO_1/1.3.6.1.4.1.9...
# 4  BENIGN_WITHOUT_CALLBACK  ...  Calc-Training_P_00008_LEFT_CC_1/1.3.6.1.4.1.95...
#
# [5 rows x 4 columns]
# Reading:  ../stuff/dataset/annotations/complete_annotations.csv
# Records:  3218
# Mask shape:(5056, 2761, 3) Max: 255 Min: 0
# Mask shape:(5386, 2836, 3) Max: 255 Min: 0
# Mask shape:(5356, 2986, 3) Max: 255 Min: 0
# Mask shape:(5491, 3166, 3) Max: 255 Min: 0
# Mask shape:(4568, 3064, 3) Max: 255 Min: 0
# Mask shape:(4568, 3064, 3) Max: 255 Min: 0
# Mask shape:(4568, 3064, 3) Max: 255 Min: 0
# Mask shape:(4528, 3056, 3) Max: 255 Min: 0
# ...

# %%
# !git clone https://github.com/ZosoV/Mammography_Mask_RCNN.git
# Out:
# Cloning into 'Mammography_Mask_RCNN'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 76 (delta 2), reused 73 (delta 2), pack-reused 0
# Unpacking objects: 100% (76/76), done.
# Checking out files: 100% (65/65), done.
